# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("Insurance.csv")

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
df=df.rename(columns={'bought_insurance':'insurance'})

# %%
df
# Out:
#     age  insurance
# 0    22          0
# 1    25          0
# 2    47          1
# 3    52          0
# 4    46          1
# 5    56          1
# 6    55          0
# 7    60          1
# 8    62          1
# 9    61          1
# 10   18          0
# 11   28          0
# 12   27          0
# 13   29          0
# 14   49          1
# 15   55          1
# 16   25          1
# 17   58          1
# 18   19          0
# 19   18          0
# 20   21          0
# 21   26          0
# 22   40          1
# 23   45          1
# 24   50          1
# 25   54          1
# 26   23          0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df[['insurance']],test_size=0.1)

# %%
x_train
# Out:
#     age
# 16   25
# 12   27
# 22   40
# 21   26
# 2    47
# 25   54
# 13   29
# 18   19
# 20   21
# 17   58
# 8    62
# 1    25
# 14   49
# 24   50
# 23   45
# 26   23
# 19   18
# 4    46
# 5    56
# 3    52
# 15   55
# 6    55
# 10   18
# 11   28

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_test
# Out:
#    age
# 9   61
# 7   60
# 0   22

# %%
y_train
# Out:
#     insurance
# 16          1
# 12          0
# 22          1
# 21          0
# 2           1
# 25          1
# 13          0
# 18          0
# 20          0
# 17          1
# 8           1
# 1           0
# 14          1
# 24          1
# 23          1
# 26          0
# 19          0
# 4           1
# 5           1
# 3           0
# 15          1
# 6           0
# 10          0
# 11          0

# %%
y_test
# Out:
#    insurance
# 9          1
# 7          1
# 0          0

# %%
plt.scatter(df.age,df.insurance)

# %%
reg=linear_model.LogisticRegression()

# %%
reg
# Out:
# LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1406: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
reg.predict([[25]])
# Out:
# C:\Users\USER\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
df
# Out:
#     age  insurance
# 0    22          0
# 1    25          0
# 2    47          1
# 3    52          0
# 4    46          1
# 5    56          1
# 6    55          0
# 7    60          1
# 8    62          1
# 9    61          1
# 10   18          0
# 11   28          0
# 12   27          0
# 13   29          0
# 14   49          1
# 15   55          1
# 16   25          1
# 17   58          1
# 18   19          0
# 19   18          0
# 20   21          0
# 21   26          0
# 22   40          1
# 23   45          1
# 24   50          1
# 25   54          1
# 26   23          0

# %%
reg.score(x_test,y_test)
# Out:
# 1.0

# %%
x_test
# Out:
#    age
# 9   61
# 7   60
# 0   22

# %%
reg.predict_proba(x_test)
# Out:
# array([[0.05571758, 0.94428242],
#        [0.06283216, 0.93716784],
#        [0.89580955, 0.10419045]])

# %%
pd.set_option('display.max_rows',None)
df1=pd.read_excel("Weather_data.xlsx")

# %%
df1
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall  Prediction
# 0           29.2      31.5        7.0       3.3           0
# 1           32.1      70.6       18.1       1.3           0
# 2           22.7      31.8        5.9       7.6           1
# 3           10.8      41.9       13.7       8.2           1
# 4           16.6      65.4       16.6       0.1           0
# 5           34.2      71.9        8.1       2.3           0
# 6           38.7      50.2        3.7       1.5           0
# 7           35.4      66.2       16.5      10.9           1
# 8           26.1      88.4        8.8       8.3           1
# 9           34.9      67.1       17.5       8.7           1
# 10          31.1      32.7        6.1       4.3           0
# 11          12.4      44.0        3.8       4.2           0
# 12          29.1      51.9        8.7       3.1           0
# 13          18.0      86.2       13.7       9.1           1
# 14          15.1      73.7        4.9       5.7           1
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(df1[['Temperature','Humidity','WindSpeed','Rainfall']],df1.Prediction,test_size=0.1)

# %%
x_train
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall
# 92          10.1      85.5       11.7      10.8
# 21          22.0      43.2       20.0       7.6
# 180         12.7      87.7       17.0       8.6
# 129         17.6      34.9        2.3       8.1
# 56          11.7      65.1       11.1      12.8
# 117         31.2      33.9        9.3       8.1
# 116         26.2      38.3        6.2      10.4
# 29          19.0      68.3       13.0       2.3
# 109         17.5      80.9       10.2      12.0
# 89          38.9      45.9        4.0       6.5
# 161         36.1      59.5       17.7       8.6
# 54          26.7      73.1        4.8       4.5
# 41          35.8      34.3        6.3      10.0
# 73          29.1      45.7       15.3       8.3
# 97          38.2      70.6       18.3       9.2
# 148         16.4      77.9        8.1      13.2
# 132         10.6      39.1        4.3      10.0
# 118         22.5      42.4        9.6      13.6
# 181         38.5      90.0       14.1       4.0
# ...

# %%
y_train
# Out:
# 92     1
# 21     1
# 180    1
# 129    1
# 56     1
# 117    1
# 116    1
# 29     0
# 109    1
# 89     1
# 161    1
# 54     0
# 41     1
# 73     1
# 97     1
# 148    1
# 132    1
# 118    1
# 181    0
# 6      0
# 151    1
# 143    1
# 166    0
# 103    0
# 22     1
# 189    1
# 104    0
# 3      1
# 131    0
# 0      0
# 58     0
# 67     0
# 75     1
# 140    1
# 156    0
# 106    0
# 128    1
# 87     1
# 39     0
# 99     1
# 74     1
# 90     1
# 136    1
# 142    1
# 121    1
# 30     1
# 152    0
# 59     1
# 138    1
# 85     0
# 77     0
# 96     1
# 134    0
# 176    1
# 13     1
# 76     1
# 112    1
# 55     1
# 49     1
# 127    0
# 12     0
# 169    0
# 68     0
# 177    1
# 10     0
# 62     1
# 111    1
# 84     1
# 46     0
# 175    0
# 171    0
# 122    0
# 26     1
# 69     1
# 162    0
# 80     1
# 48     1
# 33     1
# 125    1
# 163    1
# 105    1
# 191    1
# 8      1
# 93     0
# 9      1
# 101    1
# 123    1
# 32     0
# 57     1
# 16     0
# ...

# %%
x_test
# Out:
#      Temperature  Humidity  WindSpeed  Rainfall
# 115         12.3      47.1        6.9       4.8
# 102         29.0      50.1       16.7      11.3
# 119         27.5      71.7       17.4      11.5
# 35          24.3      63.0        6.8      13.1
# 79          22.2      67.2        4.8      13.9
# 4           16.6      65.4       16.6       0.1
# 37          16.0      48.7       19.9       9.7
# 52          21.4      89.1        6.8      11.8
# 70          31.5      42.2       13.4       4.0
# 159         15.4      30.8       11.6       4.1
# 61          16.1      73.0        6.3       5.9
# 174         29.8      86.0        9.7       8.2
# 86          19.8      81.9       19.4       4.2
# 141         35.5      79.3        3.9      14.4
# 1           32.1      70.6       18.1       1.3
# 193         14.8      63.1       11.9       1.4
# 19          37.4      57.5        6.8       3.7
# 198         36.4      81.8        7.0      11.9
# 44          12.9      55.9        9.6       7.0
# ...

# %%
y_test
# Out:
# 115    0
# 102    1
# 119    1
# 35     1
# 79     1
# 4      0
# 37     1
# 52     1
# 70     0
# 159    0
# 61     1
# 174    1
# 86     1
# 141    1
# 1      0
# 193    0
# 19     0
# 198    1
# 44     1
# 42     1
# Name: Prediction, dtype: int64

# %%
reg1=linear_model.LogisticRegression()

# %%
reg1
# Out:
# LogisticRegression()

# %%
reg1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
reg1.score(x_test,y_test)
# Out:
# 1.0
